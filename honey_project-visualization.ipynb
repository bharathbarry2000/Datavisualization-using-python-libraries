# %% [markdown]
# # Bharath Kumar. P

# %% [markdown]
# # Data Visualization on Honey Production dataset using seaborn
# # and matplotlib libraries.

# %%
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
h_df=pd.read_csv("honeyproduction (1).csv")
h_df
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %%
h_df.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
h_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.2+ KB

# %% [markdown]
# # 3. Display the percentage distribution of the data in each year using the pie chart.

# %%
plt.pie(h_df.year.unique(),labels=h_df.year.unique(),autopct='%1.1f%%')

plt.show()

# %% [markdown]
# # 4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings

# %%
P=sns.distplot(h_df.priceperlb,bins=20,kde=False,color='g')
plt.ylabel('Count of states')
plt.xlabel('Price per Pound.')
plt.show()

# %% [markdown]
# * We can see the distribution is right skewed.
# * In most of the states the price of one pound honey is 1.5 Dollars
# * The honey price ranges from 0.5  to  4 Dollars
# * Very less number of states where the price is above 3 Dollars.

# %% [markdown]
# # 5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings.

# %%
# h_df.prodvalue.max()
# import plotly.express as px
# fig=px.scatter(y='prodvalue',x='numcol',data_frame=h_df)
# fig.update_xaxes(title='Number of colonies')
# fig.update_yaxes(title='Total production value in $')
# fig.show()

sns.scatterplot('numcol','prodvalue',data=h_df)
plt.xlabel('Number of Colonies')
plt.ylabel('Total Production value in 10M')
plt.show()

# %% [markdown]
# * We can observe that there is a positive linear relationship between "number of colonies" and "total production".
# * If a state have more number of colonies then the total production is also high.

# %% [markdown]
# # 6. Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue' through boxplot, and write your findings.

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='year',y='prodvalue',data=h_df)
plt.show()

# %% [markdown]
# * We can observe there is many outlier's.
# * The median Production value for all the years lies between 0 to 0.5
# * In the recent years the productionvalue has rapidly increased.
# * The year 2010 have highest maximum productionvalue

# %% [markdown]
# # 7. Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')

# %%
plt.figure(figsize=(10,10))
sns.pairplot(h_df[['numcol', 'yieldpercol', 'totalprod', 'prodvalue','year']])
plt.show()

# %% [markdown]
# * Total production - Number of colonies
#     * We can observe that there is a positive linear relationship between "total production" & "number of colonies".
#     * If a state have more number of colonies then the total production of that state is increasing.
#
# * production value - Number of colonies
#     * We can observe that there is a positive linear relationship between "production value" & "number of colonies".
#     * If a state have more number of colonies then the total production value of that state is increasing.
#
# * production value - Total production
#     * We can observe that there is a positive linear relationship between "total production" & "Production value".
#     * If a state have more production then the production value is increasing.

# %% [markdown]
# # 8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'stocks', 'price per lb', 'prodvalue')

# %%
cdf=h_df.drop(['state','year'],axis=1)
sns.heatmap(cdf.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# * We can observe
#     * Total production vs Number of colonies
#     * Stocks vs Number of colonies
#     * Stocks vs Total production
#     * Production value vs Number of colonies
#     * Production value vs Total production
#     * Production value vs stocks
# * These above mentioned pairs are highly correlated with each other.
